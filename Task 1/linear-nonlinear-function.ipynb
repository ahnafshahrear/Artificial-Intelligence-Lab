# %% [markdown]
# ### Function: y = ax + b

# %%
import numpy as np  
import matplotlib.pyplot as plt

x = np.arange(-10, 10, 0.5, dtype = np.float64)
a = 7
b = 4
y = a * x + b

plt.plot(x, y)
plt.show()
